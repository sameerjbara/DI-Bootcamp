# %% [markdown]
# Exercise 1: Introduction to Data Analysis (Easy)
#
#
# Objective: Understand the basic overview and significance of data analysis.
# Task:
# Write a short essay or report on the following topics:
#
# What is data analysis?
# Why is data analysis important in modern contexts?
# List and describe three areas where data analysis is applied today.
# Hint/Tip:
#
# Research current trends in data analysis and real-world examples to provide depth to your essay.

# %%
# What is Data Analysis?

# Data analysis is the process of examining data to find patterns, trends, and useful information that support decision-making.

# Why is Data Analysis Important?

# It helps people and organizations make informed decisions, improve efficiency, and predict future outcomes based on data rather than guesses.

# Three Areas Where Data Analysis Is Used Today

# Business – Used to analyze sales, customers, and market trends to improve profits and strategies.

# Healthcare – Helps improve diagnosis, treatment, and patient care by analyzing medical data.

# Sports – Used to evaluate player performance and improve team strategies.

# %% [markdown]
# Exercise 2: Dataset Loading and Initial Analysis
#
#
# Objective: Practice dataset loading from Kaggle and initial analysis.
# Task:
# for the following dataset : How Much Sleep Do Americans Really Get?, Global Trends in Mental Health Disorder and Credit Card Approvals.
#
# Load the dataset into Jupyter or Google Colab.
# Display the first few rows.
# Provide a brief dataset description.

# %%
import pandas as pd

sleep_df = pd.read_csv("TimeAmericansSpendSleeping.csv")
mental_health_df = pd.read_csv("MentalHealthDepressionDisorderData.csv")
credit_df = pd.read_csv("clean_dataset.csv")
# Out:
# /tmp/ipython-input-557748362.py:4: DtypeWarning: Columns (5,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   mental_health_df = pd.read_csv("MentalHealthDepressionDisorderData.csv")

# %%
sleep_df.head()
# Out:
#    index  Year  Period  Avg hrs per day sleeping  Standard Error Type of Days  \
# 0      0  2003  Annual                      8.57           0.018     All days
# 1      1  2004  Annual                      8.55           0.026     All days
# 2      2  2005  Annual                      8.62           0.023     All days
# 3      3  2006  Annual                      8.63           0.024     All days
# 4      4  2007  Annual                      8.57           0.024     All days
#
#            Age Group  Activity   Sex
# 0  15 years and over  Sleeping  Both
# 1  15 years and over  Sleeping  Both
# 2  15 years and over  Sleeping  Both
# 3  15 years and over  Sleeping  Both
# 4  15 years and over  Sleeping  Both

# %%
mental_health_df.head()
# Out:
#    index       Entity Code  Year Schizophrenia (%) Bipolar disorder (%)  \
# 0      0  Afghanistan  AFG  1990           0.16056             0.697779
# 1      1  Afghanistan  AFG  1991          0.160312             0.697961
# 2      2  Afghanistan  AFG  1992          0.160135             0.698107
# 3      3  Afghanistan  AFG  1993          0.160037             0.698257
# 4      4  Afghanistan  AFG  1994          0.160022             0.698469
#
#   Eating disorders (%)  Anxiety disorders (%)  Drug use disorders (%)  \
# 0             0.101855               4.828830                1.677082
# 1             0.099313               4.829740                1.684746
# 2             0.096692               4.831108                1.694334
# 3             0.094336               4.830864                1.705320
# 4             0.092439               4.829423                1.716069
#
#    Depression (%)  Alcohol use disorders (%)
# 0        4.071831                   0.672404
# ...

# %%
credit_df.head()
# Out:
#    Gender    Age   Debt  Married  BankCustomer     Industry Ethnicity  \
# 0       1  30.83  0.000        1             1  Industrials     White
# 1       0  58.67  4.460        1             1    Materials     Black
# 2       0  24.50  0.500        1             1    Materials     Black
# 3       1  27.83  1.540        1             1  Industrials     White
# 4       1  20.17  5.625        1             1  Industrials     White
#
#    YearsEmployed  PriorDefault  Employed  CreditScore  DriversLicense  \
# 0           1.25             1         1            1               0
# 1           3.04             1         1            6               0
# 2           1.50             1         0            0               0
# 3           3.75             1         1            5               1
# 4           1.71             1         0            0               0
#
#         Citizen  ZipCode  Income  Approved
# 0       ByBirth      202       0         1
# ...

# %% [markdown]
# Exercise 3: Identifying Data Types
#
#
# Objective: Learn to identify different data types.
# Task:
# For the datasets from the previous exercise, categorize each column of it as either quantitative or qualitative and explain your reasoning.

# %%
# | Column                   | Type         | Reason                           |
# | ------------------------ | ------------ | -------------------------------- |
# | Year                     | Quantitative | Numeric time variable            |
# | Period                   | Qualitative  | Categorical time description     |
# | Avg hrs per day sleeping | Quantitative | Continuous numerical measurement |
# | Standard Error           | Quantitative | Statistical numeric value        |
# | Type of Days             | Qualitative  | Categorical description          |
# | Age Group                | Qualitative  | Grouped categories               |
# | Activity                 | Qualitative  | Descriptive category             |
# | Sex                      | Qualitative  | Categorical variable             |

# %%
# | Column                    | Type         | Reason                  |
# | ------------------------- | ------------ | ----------------------- |
# | Entity (Country)          | Qualitative  | Country name (category) |
# | Code                      | Qualitative  | Country code identifier |
# | Year                      | Quantitative | Numeric time value      |
# | Schizophrenia (%)         | Quantitative | Measured percentage     |
# | Bipolar disorder (%)      | Quantitative | Measured percentage     |
# | Eating disorders (%)      | Quantitative | Measured percentage     |
# | Anxiety disorders (%)     | Quantitative | Measured percentage     |
# | Drug use disorders (%)    | Quantitative | Measured percentage     |
# | Depression (%)            | Quantitative | Measured percentage     |
# | Alcohol use disorders (%) | Quantitative | Measured percentage     |

# %%
# | Column         | Type         | Reason                                             |
# | -------------- | ------------ | -------------------------------------------------- |
# | Gender         | Qualitative  | Categorical attribute (male/female encoded as 0/1) |
# | Age            | Quantitative | Numerical value representing age                   |
# | Debt           | Quantitative | Continuous numerical amount                        |
# | Married        | Qualitative  | Binary categorical status                          |
# | BankCustomer   | Qualitative  | Yes/No categorical variable                        |
# | Industry       | Qualitative  | Categorical industry type                          |
# | Ethnicity      | Qualitative  | Categorical group                                  |
# | YearsEmployed  | Quantitative | Numerical duration in years                        |
# | PriorDefault   | Qualitative  | Binary indicator                                   |
# | Employed       | Qualitative  | Employment status (Yes/No)                         |
# | CreditScore    | Quantitative | Numeric score value                                |
# | DriversLicense | Qualitative  | Binary indicator                                   |
# | Citizen        | Qualitative  | Categorical citizenship status                     |
# | ZipCode        | Qualitative  | Identifier, not numeric measurement                |
# | Income         | Quantitative | Numeric income value                               |
# | Approved       | Qualitative  | Binary outcome (approved/rejected)                 |

# %% [markdown]
# Exercise 4: Exploring Data Types
#
#
# Objective: Learn about different types of data in data analysis.
# Task:
# Load the Iris dataset using Kaggle into a Jupyter Notebook or Google Colaboratory Notebook.
# Identify and list which columns in your dataset are qualitative and which are quantitative.
# Write a brief description of why each column is classified as qualitative or quantitative.
# Tools: Jupyter Notebook, Python with Pandas library.

# %%
import pandas as pd

# Load Iris dataset
iris_df = pd.read_csv("Iris.csv")

# Display first few rows
iris_df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
# | Column            | Type         | Explanation                                                                         |
# | ----------------- | ------------ | ----------------------------------------------------------------------------------- |
# | **Id**            | Qualitative  | An identifier used to label each row; the numeric value has no quantitative meaning |
# | **SepalLengthCm** | Quantitative | Numerical measurement of sepal length in centimeters                                |
# | **SepalWidthCm**  | Quantitative | Numerical measurement of sepal width in centimeters                                 |
# | **PetalLengthCm** | Quantitative | Numerical measurement of petal length in centimeters                                |
# | **PetalWidthCm**  | Quantitative | Numerical measurement of petal width in centimeters                                 |
# | **Species**       | Qualitative  | Categorical label indicating the flower species                                     |

# %% [markdown]
# Exercise 5: Basic Data Analysis with Google Colab
#
#
# Objective: Perform basic data analysis using Google Colab.
# Task:
# Using the same notebook from the previous exercise, perform basic data analysis tasks:
# Calculate the mean, median, and mode of a quantitative column.
# Create a simple plot (like a histogram or bar chart) to visualize the data using Matplotlib/Seaborn libraries :
#
#       import matplotlib.pyplot as plt
#
#       plt.plot(data['Name_column1'], data['Name_column2'])
#
#       plt.show()
#
# Document your findings in the notebook.
# Tools: Google Colab, Python with Pandas and Matplotlib/Seaborn libraries.

# %%
import pandas as pd
import matplotlib.pyplot as plt

iris_df = pd.read_csv("Iris.csv")

# %%
column = iris_df["SepalLengthCm"]

# %%
mean_value = column.mean()
median_value = column.median()
mode_value = column.mode()[0]

mean_value, median_value, mode_value
# Out:
# (np.float64(5.843333333333334), 5.8, np.float64(5.0))

# %%
plt.hist(column, bins=10)
plt.xlabel("Sepal Length (cm)")
plt.ylabel("Frequency")
plt.title("Distribution of Sepal Length")
plt.show()

# %% [markdown]
# 🌟Exercise 6: Basic Observation Skills in Data Analysis
#
#
# Objective: Develop observation skills for data analysis.
# Task:
# Load the How Much Sleep Do Americans Really Get? dataset into Jupyter or Google Colab.
# Identify columns that could be interesting for a specific type of analysis (e.g., trend analysis, group comparison) and explain your choice.
# Tools: Jupyter Notebook, Python with Pandas library.

# %%
import pandas as pd

sleep_df = pd.read_csv("sleep_americans.csv")
sleep_df.head()

# %%
# Trend Analysis

# Year
# Useful for analyzing how average sleep duration changes over time.

# Avg hrs per day sleeping
# Main quantitative variable to observe long-term sleep trends.

# Period
# Helps distinguish between annual or other time-based reporting periods.

# These columns allow us to see whether Americans are sleeping more or less over the years.

# Group Comparison

# Age Group
# Allows comparison of sleep duration between different age ranges.

# Sex
# Useful for comparing sleep patterns between males and females.

# Type of Days
# Enables comparison between weekdays, weekends, or all days.

# These categorical columns help analyze differences in sleep behavior across population groups.
